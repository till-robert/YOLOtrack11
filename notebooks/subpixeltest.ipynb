# %%
import numpy as np
import matplotlib.pyplot as plt
import image_generator as ig
import pandas as pd
refstack = np.zeros((1, 4,4))
refstack[:,1,1]=1e4

# %%
image_size=10,10
params =[{"n":1,"label":"R", "z":0,"i":1}]
objects = pd.DataFrame({"x":5,"y":6,**params[0]}, index=[0])

# %%
plt.imshow(ig.generateImage(objects, image_size, refstack=refstack, refstack_center=(1,1)))
