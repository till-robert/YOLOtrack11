# %%
import numpy as np
import matplotlib.pyplot as plt
import image_generator as ig
import pandas as pd
from importlib import reload
refstack = np.zeros((2, 4,4))
refstack[0,1:3,1:3]=1

# %%
reload(ig)
image_size=10,10
params =[{"n":1,"label":"R", "z":0.5,"i":2}]
objects = pd.DataFrame({"x":5.75,"y":4.5,**params[0]}, index=[0])

# %%
plt.imshow(ig.generateImage(objects, image_size, refstack=refstack, refstack_center=(1.5,1.5)))
plt.plot(objects.x, objects.y, "ro")
plt.colorbar()
